# %% [markdown]
# ## product of digits

# %%
def prodDigits(n):
    prod=1
    while n!=0:
        prod=prod*(n%10)
        n=n//10
    return prod
print(prodDigits(453))
# Out:
# 60

# %%
def prodDigits(n):
    prod=1
    while n!=0:
        prod=prod*(n%10)
        n=n//10
    return prod
print(prodDigits(666))
# Out:
# 216
